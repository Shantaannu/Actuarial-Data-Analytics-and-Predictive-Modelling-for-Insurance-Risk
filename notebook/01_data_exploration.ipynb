# %%
import pandas as pd
from tabulate import tabulate

# %%
import sys
from pathlib import Path
sys.path.insert(0,str(Path.cwd().parent))
from packages.data_import import df_claims, df_claims_premium

# %%
print("Claims DataFrame:")
print(tabulate(df_claims, headers='keys', tablefmt='psql'))
# Out:
# Claims DataFrame:
# +-----+--------+-------------------+-------------------------------+-----------------------------+-----------------+
# |     |   Year |   AccidentQuarter | Measure                       | ClaimType                   |           Value |
# |-----+--------+-------------------+-------------------------------+-----------------------------+-----------------|
# |   0 |   2010 |            201003 | Ultimate Costs                | Accidental Damage           |     3.75507e+07 |
# |   1 |   2010 |            201006 | Ultimate Costs                | Accidental Damage           |     2.5304e+07  |
# |   2 |   2010 |            201009 | Ultimate Costs                | Accidental Damage           |     2.47236e+07 |
# |   3 |   2010 |            201012 | Ultimate Costs                | Accidental Damage           |     3.71483e+07 |
# |   4 |   2011 |            201103 | Ultimate Costs                | Accidental Damage           |     2.75393e+07 |
# ...

# %%
print("Claims Premium DataFrame:")
print(tabulate(df_claims_premium, headers='keys', tablefmt='psql'))
# Out:
# Claims Premium DataFrame:
# +-----+--------+---------+-----------+----------------------+---------------+------------------+
# |     |   Year | YearH   |   Quarter | Measure              | CoverType     |            Value |
# |-----+--------+---------+-----------+----------------------+---------------+------------------|
# |   0 |   2010 | 2010H1  |    201003 | Gross Earned Premium | Comprehensive |      1.70439e+08 |
# |   1 |   2010 | 2010H1  |    201006 | Gross Earned Premium | Comprehensive |      1.70735e+08 |
# |   2 |   2010 | 2010H2  |    201009 | Gross Earned Premium | Comprehensive |      1.73142e+08 |
# |   3 |   2010 | 2010H2  |    201012 | Gross Earned Premium | Comprehensive |      1.72933e+08 |
# |   4 |   2011 | 2011H1  |    201103 | Gross Earned Premium | Comprehensive |      1.7082e+08  |
# |   5 |   2011 | 2011H1  |    201106 | Gross Earned Premium | Comprehensive |      1.72686e+08 |
# ...

# %%
print("Claims dataset:", claims_clean.shape)
print("Premium dataset:", premium_clean.shape)

# %%
#Dataframe information for df_claims, df_claims_premium

print("Claims DataFrame Information:")
print(df_claims.info())
print("Claims Premium DataFrame Information:")
print(df_claims_premium.info())
# Out:
# Claims DataFrame Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             840 non-null    int64
#  1   AccidentQuarter  840 non-null    int64
#  2   Measure          840 non-null    str
#  3   ClaimType        840 non-null    str
#  4   Value            840 non-null    float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 32.9 KB
# None
# Claims Premium DataFrame Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       240 non-null    int64
#  1   YearH      240 non-null    str
#  2   Quarter    240 non-null    int64
#  3   Measure    240 non-null    str
#  4   CoverType  240 non-null    str
#  5   Value      240 non-null    float64
# ...
